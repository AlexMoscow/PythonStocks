# ## Построение графика средней скользащей

# %%
df['MA'] = moving_average(df, 5)
plt.plot(df.index,df['Close'], label='close')
plt.plot(df.index,df['MA'],label='MA', color = 'red')
plt.legend()
plt.title('Microsoft')
plt.ylabel('Price($)')
plt.show()

# %% [markdown]
# ## RSI
# ![RSI-formula.png](img/RSI-formula.png)

# %%
def RSI(series, n):
    delta = series.diff().dropna()
    u = delta * 0
    d = u.copy()
    u[delta > 0] = delta[delta > 0]
    d[delta < 0] = -delta[delta < 0]
    u[u.index[n-1]] = np.mean( u[:n] ) 
    u = u.drop(u.index[:(n-1)])
    d[d.index[n-1]] = np.mean( d[:n] ) 
    d = d.drop(d.index[:(n-1)])
    rs = pd.Series.ewm(u, com=n-1, adjust=False).mean()  / pd.Series.ewm(d, com=n-1, adjust=False).mean()
    return 100 - 100 / (1 + rs)
df['RSI'] = RSI(df.Close, 5)
df.plot(y=['RSI'])

# %% [markdown]
# ## Стохастический осциллятор
# ![stochastic-1.png](img/stochastic-1.png)
#
# где N – количество периодов;
#
# Ct – цена закрытия в период времени t;
#
# HN – максимальное значение цены за последние N периодов;
#
# LN – минимальное значение цены за последние N периодов.
#
# Формула расчета %D в период времени t представляет собой простое скользящее среднее %K с интервалом сглаживания m.
#
# ![stochastic-2.png](img/stochastic-2.png)

# %%
#Стохастик индикатор

def stochastic_oscillator(Close, Low, High, n, k):
    SOk = ((Close-pd.Series(Low.rolling(window = n).min())) / (pd.Series(High.rolling(window = n).max()) - pd.Series(Low.rolling(window = n).min()))) * 100
    SOk = pd.Series(SOk.rolling(window = k).mean())
    SOd = pd.Series(SOk.rolling(window = k).mean())
    return SOd
df['Stochastic'] = stochastic_oscillator(df['Close'],df['Low'],df['High'], 5, 3)
df.plot(y=['Stochastic'])

# %%
close_group = df['Close']

# применяю lambda функцию, которая возвращает -1 при отрицательном занчении, 0 при равном, 1 при положительном
close_group = close_group.transform(lambda x : np.sign(x.diff()))

df['Prediction'] = close_group

# равные дни приравниваем к положительным
df.loc[df['Prediction'] == 0.0, 'Prediction'] = 1.0

df.tail(50)
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in sign
#   after removing the cwd from sys.path.
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-10-18  139.759995  140.000000  136.559998  137.410004  136.570984
# 2019-10-21  138.449997  138.500000  137.009995  138.429993  137.584747
# 2019-10-22  138.970001  140.009995  136.259995  136.369995  135.537338
# 2019-10-23  136.880005  137.449997  135.610001  137.240005  136.402039
# 2019-10-24  139.389999  140.419998  138.669998  139.940002  139.085556
# 2019-10-25  139.339996  141.139999  139.199997  140.729996  139.870712
# 2019-10-28  144.399994  145.669998  143.509995  144.190002  143.309601
# 2019-10-29  144.080002  144.500000  142.649994  142.830002  141.957901
# 2019-10-30  143.520004  145.000000  142.789993  144.610001  143.727036
# 2019-10-31  144.899994  144.929993  142.990005  143.369995  142.494583
# 2019-11-01  144.259995  144.419998  142.970001  143.720001  142.842468
# 2019-11-04  144.830002  145.000000  144.160004  144.550003  143.667404
# 2019-11-05  144.970001  145.020004  143.910004  144.460007  143.577957
# 2019-11-06  144.369995  144.520004  143.199997  144.059998  143.180374
# 2019-11-07  143.839996  144.880005  143.770004  144.259995  143.379150
# 2019-12-11   18856600  151.173999  65.836641   79.683294         1.0
# 2019-12-12   24612100  151.836002  78.708252   79.534696         1.0
# 2019-12-13   23845400  152.392001  84.731623   81.821533         1.0
# 2019-12-16   24144200  153.226001  88.016591   87.266348         1.0
# 2019-12-17   25425600  153.938000  71.797240   90.000814        -1.0
# 2019-12-18   24129200  154.472000  66.005101   87.019354        -1.0
# 2019-12-19   24958900  154.966000  76.098134   82.750692         1.0
# 2019-12-20   53477500  155.542001  83.749324   80.076798         1.0
# 2019-12-23   17718200  155.918002  83.749324   80.961285         1.0
# 2019-12-24    8989200  156.456003  83.016604   79.880959        -1.0
# 2019-12-26   14520600  157.316003  88.448816   81.316353         1.0
# 2019-12-27   18412800  157.966003  89.401462   82.320542         1.0
# 2019-12-30   16348400  158.002002  60.122074   80.118429        -1.0
#
# [1250 rows x 10 columns]

# %% [markdown]
# ### Разделяю датафрейм на тренировочное и тестовое мн-ва

# %%
X = df[['Close', 'MA','RSI','Stochastic']]
Y = df['Prediction']
xTrain, xTest, yTrain, yTest = train_test_split(X, Y, test_size = 0.2, shuffle = False)

# %% [markdown]
# ## Random forest

# %%
rand_fr = RandomForestClassifier(n_estimators = 100, oob_score = True, criterion = "gini", random_state = 0)
rand_fr.fit(xTrain, yTrain)
y_pred = rand_fr.predict(xTest)

# accuracy
print('Correct Prediction (%): ', accuracy_score(yTest, y_pred, normalize = True) * 100.0)
# Out:
# Correct Prediction (%):  76.4

# %% [markdown]
# ## SVC

# %%
clf = SVC(kernel='linear', C=1)
clf.fit(xTrain, yTrain)
y_pred1 = clf.predict(xTest)

print('Correct Prediction (%): ', accuracy_score(yTest, y_pred1, normalize = True) * 100.0)
# Out:
# Correct Prediction (%):  80.4

# %% [markdown]
# ### Создаю новый датафрейм для тестирования

# %%
df['y_pred1'] = np.NaN
df.iloc[(len(df) - len(y_pred)):, -1] = y_pred1

df1 = pd.DataFrame(index = df.index) 
df1['Open'] = df['Open'].values      
df1['High'] = df['High'].values      
df1['Low'] = df['Low'].values
df1['Close'] = df['Close'].values
df1['Volume'] = df['Volume'].values
df1['openinterest'] = df['y_pred1'].values
df1
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Anaconda\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#                   Open        High         Low       Close     Volume  \
# Date
# 2015-01-13   46.970001   47.910000   46.060001   46.360001   35270600
# 2015-01-14   45.959999   46.240002   45.619999   45.959999   29719600
# 2015-01-15   46.220001   46.380001   45.410000   45.480000   32750800
# 2015-01-16   45.310001   46.279999   45.169998   46.240002   35695300
# 2015-01-20   46.299999   46.650002   45.570000   46.389999   36161900
# 2015-01-21   45.939999   46.139999   45.480000   45.919998   39081100
# 2015-01-22   46.380001   47.139999   46.080002   47.130001   35898000
# 2015-01-23   47.360001   47.389999   46.799999   47.180000   26211600
# 2015-01-26   47.000000   47.130001   46.240002   47.009998   42525500
# 2015-01-27   42.950001   43.200001   42.110001   42.660000  169164000
# 2015-01-28   42.740002   42.790001   41.160000   41.189999   84507100
# 2015-01-29   40.930000   42.119999   40.790001   42.009998   63585300
# 2015-01-30   41.549999   41.580002   40.349998   40.400002   78004900
# 2019-02-05           1.0
# 2019-02-06          -1.0
# 2019-02-07          -1.0
# 2019-02-08          -1.0
# 2019-02-11          -1.0
# 2019-02-12           1.0
# 2019-02-13           1.0
# 2019-02-14           1.0
# ...                  ...
# 2019-11-15           1.0
# 2019-11-18           1.0
# 2019-11-19           1.0
# 2019-11-20          -1.0
# 2019-11-21          -1.0
# 2019-11-22           1.0
# 2019-11-25           1.0
# 2019-11-26           1.0
# 2019-11-27           1.0
# 2019-11-29          -1.0
# 2019-12-02          -1.0
# 2019-12-03          -1.0
# 2019-12-04          -1.0
# 2019-12-05          -1.0
# 2019-12-06           1.0
# 2019-12-09           1.0
# 2019-12-10          -1.0
# 2019-12-11           1.0
# 2019-12-12           1.0
# 2019-12-13           1.0
# 2019-12-16           1.0
# 2019-12-17           1.0
# 2019-12-18          -1.0
# 2019-12-19           1.0
# 2019-12-20           1.0
# 2019-12-23           1.0
# 2019-12-24           1.0
# 2019-12-26           1.0
# 2019-12-27           1.0
# 2019-12-30          -1.0
#
# [250 rows x 6 columns]

# %% [markdown]
# ## Создание стратегии для торговли

# %%
# Create a Strategy
class RF_Signal(bt.Strategy):

    def log(self, txt, dt = None):
        ''' Logging function for this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        # Keep a reference to the "close" line in the data[0] dataseries
        self.dataclose = self.datas[0].close
        self.datasignal = self.datas[0].openinterest
        
        # To keep track of pending orders and buy price/commission
        self.order = None
        self.buyprice = None
        self.buycomm = None
                
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(
                    'BUY ORDER EXECUTED, Price: %.2f, Cost: %.2f, Commission: %.2f' %
                    (order.executed.price,
                     order.executed.value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else:  # Sell
                self.log('SELL ORDER EXECUTED, Price: %.2f, Cost: %.2f, Commission: %.2f' %
                         (order.executed.price,
                          order.executed.value,
                          order.executed.comm))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        # Write down: no pending order
        self.order = None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log('OPERATING PROFIT, GROSS: %.2f, NET: %.2f' % (trade.pnl, trade.pnlcomm))

    def next(self):
        # Simply log the closing price of the series from the reference
        self.log('Close, %.2f' % self.dataclose[0])
        self.log('y_pred, %.2f' % self.datasignal[0])
        
        # Check if an order is pending ... if yes, we cannot send a 2nd one
        if self.order:
            return

        # Check if we are in the market
        if not self.position:

            # Not yet ... we MIGHT BUY if y_pred > 0
            if self.datasignal[0] > 0:
                # BUY
                self.log('BUY ORDER CREATED, %.2f' % self.dataclose[0])

                # Keep track of the created order to avoid a 2nd order
                self.order = self.buy()
        else:
            # sell if y_pred < 0
            if self.datasignal[0] < 0:
                # SELL
                self.log('SELL ORDER CREATED, %.2f' % self.dataclose[0])

                # Keep track of the created order to avoid a 2nd order
                self.order = self.sell()

# %% [markdown]
# ### Добавление TradeAnalyzer

# %%
def printTradeAnalysis(analyzer):
    '''
    Function to print the Technical Analysis results in a nice format.
    '''
    #Get the results we are interested in
    total_open = analyzer.total.open
    total_closed = analyzer.total.closed
    total_won = analyzer.won.total
    total_lost = analyzer.lost.total
    win_streak = analyzer.streak.won.longest
    lose_streak = analyzer.streak.lost.longest
    pnl_net = round(analyzer.pnl.net.total,2)
    strike_rate = round((total_won / total_closed) * 100, 2)
    #Designate the rows
    h1 = ['Total Open', 'Total Closed', 'Total Won', 'Total Lost']
    h2 = ['Strike Rate','Win Streak', 'Losing Streak', 'PnL Net']
    r1 = [total_open, total_closed,total_won,total_lost]
    r2 = [strike_rate, win_streak, lose_streak, pnl_net]
    #Check which set of headers is the longest.
    if len(h1) > len(h2):
        header_length = len(h1)
    else:
        header_length = len(h2)
    #Print the rows
    print_list = [h1,r1,h2,r2]
    row_format ="{:<15}" * (header_length + 1)
    print("Trade Analysis Results:")
    for row in print_list:
        print(row_format.format('',*row))

# %% [markdown]
# ## Запуск теста

# %%
# Create a cerebro entity
cerebro = bt.Cerebro()

# Add a strategy
cerebro.addstrategy(RF_Signal)

# Create a Data Feed
data = bt.feeds.PandasDirectData(dataname = clean_df1)
# Add the Data Feed to Cerebro
cerebro.adddata(data)

# Set our desired cash start
cerebro.broker.setcash(1000000.0)

# Add a FixedSize sizer according to the stake
cerebro.addsizer(bt.sizers.FixedSize, stake = 100)

# Set the commission
cerebro.broker.setcommission(commission = 0.001)

# Print out the starting conditions
print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())


# Analyzer
cerebro.addanalyzer(bt.analyzers.SharpeRatio, _name = 'mySharpe')
cerebro.addanalyzer(bt.analyzers.DrawDown, _name = 'myDrawDown')
cerebro.addanalyzer(bt.analyzers.TradeAnalyzer, _name='ta')

results = cerebro.run()
strat = results[0]

# Print out the final result
print('\nFinal Portfolio Value: %.2f' % cerebro.broker.getvalue())
##print('Sharpe Ratio:', strat.analyzers.mySharpe.get_analysis())
##print('Drawdown :', strat.analyzers.myDrawDown.get_analysis())

printTradeAnalysis(strat.analyzers.ta.get_analysis())

cerebro.plot(style='line')
# Out:
# Starting Portfolio Value: 1000000.00
# 2019-01-03, Close, 97.40
# 2019-01-03, y_pred, -1.00
# 2019-01-04, Close, 101.93
# 2019-01-04, y_pred, 1.00
# 2019-01-04, BUY ORDER CREATED, 101.93
# 2019-01-07, BUY ORDER EXECUTED, Price: 101.64, Cost: 10164.00, Commission: 10.16
# 2019-01-07, Close, 102.06
# 2019-01-07, y_pred, 1.00
# 2019-01-08, Close, 102.80
# 2019-01-08, y_pred, 1.00
# 2019-01-09, Close, 104.27
# 2019-01-09, y_pred, 1.00
# 2019-01-10, Close, 103.60
# 2019-01-10, y_pred, -1.00
# 2019-01-10, SELL ORDER CREATED, 103.60
# 2019-01-11, SELL ORDER EXECUTED, Price: 103.19, Cost: 10164.00, Commission: 10.32
# 2019-01-11, OPERATING PROFIT, GROSS: 155.00, NET: 134.52
# 2019-01-11, Close, 102.80
# 2019-01-11, y_pred, -1.00
# 2019-01-14, Close, 102.05
# 2019-01-14, y_pred, -1.00
# 2019-01-15, Close, 105.01
# 2019-01-15, y_pred, 1.00
# 2019-01-15, BUY ORDER CREATED, 105.01
# 2019-01-16, BUY ORDER EXECUTED, Price: 105.26, Cost: 10526.00, Commission: 10.53
# 2019-01-16, Close, 105.38
# 2019-01-16, y_pred, 1.00
# 2019-01-17, Close, 106.12
# 2019-01-17, y_pred, 1.00
# 2019-01-18, Close, 107.71
# 2019-01-18, y_pred, 1.00
# 2019-01-22, Close, 105.68
# 2019-01-22, y_pred, -1.00
# 2019-01-22, SELL ORDER CREATED, 105.68
# 2019-01-23, SELL ORDER EXECUTED, Price: 106.12, Cost: 10526.00, Commission: 10.61
# 2019-01-23, OPERATING PROFIT, GROSS: 86.00, NET: 64.86
# 2019-01-23, Close, 106.71
# 2019-01-23, y_pred, -1.00
# 2019-01-24, Close, 106.20
# 2019-01-24, y_pred, -1.00
# 2019-01-25, Close, 107.17
# 2019-01-25, y_pred, 1.00
# 2019-01-25, BUY ORDER CREATED, 107.17
# 2019-01-28, BUY ORDER EXECUTED, Price: 106.26, Cost: 10626.00, Commission: 10.63
# 2019-01-28, Close, 105.08
# 2019-01-28, y_pred, -1.00
# 2019-01-28, SELL ORDER CREATED, 105.08
# 2019-01-29, SELL ORDER EXECUTED, Price: 104.88, Cost: 10626.00, Commission: 10.49
# 2019-01-29, OPERATING PROFIT, GROSS: -138.00, NET: -159.11
# 2019-01-29, Close, 102.94
# 2019-01-29, y_pred, -1.00
# 2019-01-30, Close, 106.38
# 2019-01-30, y_pred, 1.00
# 2019-01-30, BUY ORDER CREATED, 106.38
# 2019-01-31, BUY ORDER EXECUTED, Price: 103.80, Cost: 10380.00, Commission: 10.38
# 2019-01-31, Close, 104.43
# 2019-01-31, y_pred, -1.00
# 2019-01-31, SELL ORDER CREATED, 104.43
# 2019-02-01, SELL ORDER EXECUTED, Price: 103.78, Cost: 10380.00, Commission: 10.38
# 2019-02-01, OPERATING PROFIT, GROSS: -2.00, NET: -22.76
# 2019-02-01, Close, 102.78
# 2019-02-01, y_pred, -1.00
# 2019-02-04, Close, 105.74
# 2019-02-04, y_pred, 1.00
# 2019-02-04, BUY ORDER CREATED, 105.74
# 2019-02-05, BUY ORDER EXECUTED, Price: 106.06, Cost: 10606.00, Commission: 10.61
# 2019-02-05, Close, 107.22
# 2019-02-05, y_pred, 1.00
# 2019-02-06, Close, 106.03
# 2019-02-06, y_pred, -1.00
# 2019-02-06, SELL ORDER CREATED, 106.03
# 2019-02-07, SELL ORDER EXECUTED, Price: 105.19, Cost: 10606.00, Commission: 10.52
# 2019-02-07, OPERATING PROFIT, GROSS: -87.00, NET: -108.12
# 2019-02-07, Close, 105.27
# 2019-02-07, y_pred, -1.00
# 2019-02-08, Close, 105.67
# 2019-02-08, y_pred, -1.00
# 2019-02-11, Close, 105.25
# 2019-02-11, y_pred, -1.00
# 2019-02-12, Close, 106.89
# 2019-02-12, y_pred, 1.00
# 2019-02-12, BUY ORDER CREATED, 106.89
# 2019-02-13, BUY ORDER EXECUTED, Price: 107.50, Cost: 10750.00, Commission: 10.75
# 2019-02-13, Close, 106.81
# 2019-02-13, y_pred, 1.00
# 2019-02-14, Close, 106.90
# 2019-02-14, y_pred, 1.00
# 2019-02-15, Close, 108.22
# 2019-02-15, y_pred, 1.00
# 2019-02-19, Close, 108.17
# 2019-02-19, y_pred, 1.00
# 2019-02-20, Close, 107.15
# 2019-02-20, y_pred, -1.00
# 2019-02-20, SELL ORDER CREATED, 107.15
# 2019-02-21, SELL ORDER EXECUTED, Price: 106.90, Cost: 10750.00, Commission: 10.69
# 2019-02-21, OPERATING PROFIT, GROSS: -60.00, NET: -81.44
# 2019-02-21, Close, 109.41
# 2019-02-21, y_pred, 1.00
# 2019-02-21, BUY ORDER CREATED, 109.41
# 2019-02-22, BUY ORDER EXECUTED, Price: 110.05, Cost: 11005.00, Commission: 11.01
# 2019-02-22, Close, 110.97
# 2019-02-22, y_pred, 1.00
# 2019-02-25, Close, 111.59
# 2019-02-25, y_pred, 1.00
# 2019-02-26, Close, 112.36
# 2019-02-26, y_pred, 1.00
# 2019-02-27, Close, 112.17
# 2019-02-27, y_pred, 1.00
# 2019-02-28, Close, 112.03
# 2019-02-28, y_pred, 1.00
# 2019-03-01, Close, 112.53
# 2019-03-01, y_pred, 1.00
# 2019-03-04, Close, 112.26
# 2019-03-04, y_pred, 1.00
# 2019-03-05, Close, 111.70
# 2019-03-05, y_pred, -1.00
# 2019-03-05, SELL ORDER CREATED, 111.70
# 2019-03-06, SELL ORDER EXECUTED, Price: 111.87, Cost: 11005.00, Commission: 11.19
# 2019-03-06, OPERATING PROFIT, GROSS: 182.00, NET: 159.81
# 2019-03-06, Close, 111.75
# 2019-03-06, y_pred, 1.00
# 2019-03-06, BUY ORDER CREATED, 111.75
# 2019-03-07, BUY ORDER EXECUTED, Price: 111.40, Cost: 11140.00, Commission: 11.14
# 2019-03-07, Close, 110.39
# 2019-03-07, y_pred, -1.00
# 2019-03-07, SELL ORDER CREATED, 110.39
# 2019-03-08, SELL ORDER EXECUTED, Price: 109.16, Cost: 11140.00, Commission: 10.92
# 2019-03-08, OPERATING PROFIT, GROSS: -224.00, NET: -246.06
# 2019-03-08, Close, 110.51
# 2019-03-08, y_pred, -1.00
# 2019-03-11, Close, 112.83
# 2019-03-11, y_pred, 1.00
# 2019-03-11, BUY ORDER CREATED, 112.83
# 2019-03-12, BUY ORDER EXECUTED, Price: 112.82, Cost: 11282.00, Commission: 11.28
# 2019-03-12, Close, 113.62
# 2019-03-12, y_pred, 1.00
# 2019-03-13, Close, 114.50
# 2019-03-13, y_pred, 1.00
# 2019-03-14, Close, 114.59
# 2019-03-14, y_pred, 1.00
# 2019-03-15, Close, 115.91
# 2019-03-15, y_pred, 1.00
# 2019-03-18, Close, 117.57
# 2019-03-18, y_pred, 1.00
# 2019-03-19, Close, 117.65
# 2019-03-19, y_pred, 1.00
# 2019-03-20, Close, 117.52
# 2019-03-20, y_pred, 1.00
# 2019-03-21, Close, 120.22
# 2019-03-21, y_pred, 1.00
# 2019-03-22, Close, 117.05
# 2019-03-22, y_pred, -1.00
# 2019-03-22, SELL ORDER CREATED, 117.05
# 2019-03-25, SELL ORDER EXECUTED, Price: 116.56, Cost: 11282.00, Commission: 11.66
# 2019-03-25, OPERATING PROFIT, GROSS: 374.00, NET: 351.06
# 2019-03-25, Close, 117.66
# 2019-03-25, y_pred, -1.00
# 2019-03-26, Close, 117.91
# 2019-03-26, y_pred, 1.00
# 2019-03-26, BUY ORDER CREATED, 117.91
# 2019-03-27, BUY ORDER EXECUTED, Price: 117.88, Cost: 11788.00, Commission: 11.79
# 2019-03-27, Close, 116.77
# 2019-03-27, y_pred, -1.00
# 2019-03-27, SELL ORDER CREATED, 116.77
# 2019-03-28, SELL ORDER EXECUTED, Price: 117.44, Cost: 11788.00, Commission: 11.74
# 2019-03-28, OPERATING PROFIT, GROSS: -44.00, NET: -67.53
# 2019-03-28, Close, 116.93
# 2019-03-28, y_pred, 1.00
# 2019-03-28, BUY ORDER CREATED, 116.93
# 2019-03-29, BUY ORDER EXECUTED, Price: 118.07, Cost: 11807.00, Commission: 11.81
# 2019-03-29, Close, 117.94
# 2019-03-29, y_pred, 1.00
# 2019-04-01, Close, 119.02
# 2019-04-01, y_pred, 1.00
# 2019-04-02, Close, 119.19
# 2019-04-02, y_pred, 1.00
# 2019-04-03, Close, 119.97
# 2019-04-03, y_pred, 1.00
# 2019-04-04, Close, 119.36
# 2019-04-04, y_pred, -1.00
# 2019-04-04, SELL ORDER CREATED, 119.36
# 2019-04-05, SELL ORDER EXECUTED, Price: 119.39, Cost: 11807.00, Commission: 11.94
# 2019-04-05, OPERATING PROFIT, GROSS: 132.00, NET: 108.25
# 2019-04-05, Close, 119.89
# 2019-04-05, y_pred, 1.00
# 2019-04-05, BUY ORDER CREATED, 119.89
# 2019-04-08, BUY ORDER EXECUTED, Price: 119.81, Cost: 11981.00, Commission: 11.98
# 2019-04-08, Close, 119.93
# 2019-04-08, y_pred, 1.00
# 2019-04-09, Close, 119.28
# 2019-04-09, y_pred, -1.00
# 2019-04-09, SELL ORDER CREATED, 119.28
# 2019-04-10, SELL ORDER EXECUTED, Price: 119.76, Cost: 11981.00, Commission: 11.98
# 2019-04-10, OPERATING PROFIT, GROSS: -5.00, NET: -28.96
# 2019-04-10, Close, 120.19
# 2019-04-10, y_pred, 1.00
# 2019-04-10, BUY ORDER CREATED, 120.19
# 2019-04-11, BUY ORDER EXECUTED, Price: 120.54, Cost: 12054.00, Commission: 12.05
# 2019-04-11, Close, 120.33
# 2019-04-11, y_pred, 1.00
# 2019-04-12, Close, 120.95
# 2019-04-12, y_pred, 1.00
# 2019-04-15, Close, 121.05
# 2019-04-15, y_pred, 1.00
# 2019-04-16, Close, 120.77
# 2019-04-16, y_pred, -1.00
# 2019-04-16, SELL ORDER CREATED, 120.77
# 2019-04-17, SELL ORDER EXECUTED, Price: 121.24, Cost: 12054.00, Commission: 12.12
# 2019-04-17, OPERATING PROFIT, GROSS: 70.00, NET: 45.82
# 2019-04-17, Close, 121.77
# 2019-04-17, y_pred, 1.00
# 2019-04-17, BUY ORDER CREATED, 121.77
# 2019-04-18, BUY ORDER EXECUTED, Price: 122.19, Cost: 12219.00, Commission: 12.22
# 2019-04-18, Close, 123.37
# 2019-04-18, y_pred, 1.00
# 2019-04-22, Close, 123.76
# 2019-04-22, y_pred, 1.00
# 2019-04-23, Close, 125.44
# 2019-04-23, y_pred, 1.00
# 2019-04-24, Close, 125.01
# 2019-04-24, y_pred, 1.00
# 2019-04-25, Close, 129.15
# 2019-04-25, y_pred, 1.00
# 2019-04-26, Close, 129.89
# 2019-04-26, y_pred, 1.00
# 2019-04-29, Close, 129.77
# 2019-04-29, y_pred, 1.00
# 2019-04-30, Close, 130.60
# 2019-04-30, y_pred, 1.00
# 2019-05-01, Close, 127.88
# 2019-05-01, y_pred, -1.00
# 2019-05-01, SELL ORDER CREATED, 127.88
# 2019-05-02, SELL ORDER EXECUTED, Price: 127.98, Cost: 12219.00, Commission: 12.80
# 2019-05-02, OPERATING PROFIT, GROSS: 579.00, NET: 553.98
# 2019-05-02, Close, 126.21
# 2019-05-02, y_pred, -1.00
# 2019-05-03, Close, 128.90
# 2019-05-03, y_pred, 1.00
# 2019-05-03, BUY ORDER CREATED, 128.90
# 2019-05-06, BUY ORDER EXECUTED, Price: 126.39, Cost: 12639.00, Commission: 12.64
# 2019-05-06, Close, 128.15
# 2019-05-06, y_pred, 1.00
# 2019-05-07, Close, 125.52
# 2019-05-07, y_pred, -1.00
# 2019-05-07, SELL ORDER CREATED, 125.52
# 2019-05-08, SELL ORDER EXECUTED, Price: 125.44, Cost: 12639.00, Commission: 12.54
# 2019-05-08, OPERATING PROFIT, GROSS: -95.00, NET: -120.18
# 2019-05-08, Close, 125.51
# 2019-05-08, y_pred, -1.00
# 2019-05-09, Close, 125.50
# 2019-05-09, y_pred, -1.00
# 2019-05-10, Close, 127.13
# 2019-05-10, y_pred, 1.00
# 2019-05-10, BUY ORDER CREATED, 127.13
# 2019-05-13, BUY ORDER EXECUTED, Price: 124.11, Cost: 12411.00, Commission: 12.41
# 2019-05-13, Close, 123.35
# 2019-05-13, y_pred, -1.00
# 2019-05-13, SELL ORDER CREATED, 123.35
# 2019-05-14, SELL ORDER EXECUTED, Price: 123.87, Cost: 12411.00, Commission: 12.39
# 2019-05-14, OPERATING PROFIT, GROSS: -24.00, NET: -48.80
# 2019-05-14, Close, 124.73
# 2019-05-14, y_pred, -1.00
# 2019-05-15, Close, 126.02
# 2019-05-15, y_pred, 1.00
# 2019-05-15, BUY ORDER CREATED, 126.02
# 2019-05-16, BUY ORDER EXECUTED, Price: 126.75, Cost: 12675.00, Commission: 12.68
# 2019-05-16, Close, 128.93
# 2019-05-16, y_pred, 1.00
# 2019-05-17, Close, 128.07
# 2019-05-17, y_pred, 1.00
# 2019-05-20, Close, 126.22
# 2019-05-20, y_pred, -1.00
# 2019-05-20, SELL ORDER CREATED, 126.22
# 2019-05-21, SELL ORDER EXECUTED, Price: 127.43, Cost: 12675.00, Commission: 12.74
# 2019-05-21, OPERATING PROFIT, GROSS: 68.00, NET: 42.58
# 2019-05-21, Close, 126.90
# 2019-05-21, y_pred, -1.00
# 2019-05-22, Close, 127.67
# 2019-05-22, y_pred, 1.00
# 2019-05-22, BUY ORDER CREATED, 127.67
# 2019-05-23, BUY ORDER EXECUTED, Price: 126.20, Cost: 12620.00, Commission: 12.62
# 2019-05-23, Close, 126.18
# 2019-05-23, y_pred, -1.00
# 2019-05-23, SELL ORDER CREATED, 126.18
# 2019-05-24, SELL ORDER EXECUTED, Price: 126.91, Cost: 12620.00, Commission: 12.69
# 2019-05-24, OPERATING PROFIT, GROSS: 71.00, NET: 45.69
# 2019-05-24, Close, 126.24
# 2019-05-24, y_pred, -1.00
# 2019-05-28, Close, 126.16
# 2019-05-28, y_pred, -1.00
# 2019-05-29, Close, 124.94
# 2019-05-29, y_pred, -1.00
# 2019-05-30, Close, 125.73
# 2019-05-30, y_pred, 1.00
# 2019-05-30, BUY ORDER CREATED, 125.73
# 2019-05-31, BUY ORDER EXECUTED, Price: 124.23, Cost: 12423.00, Commission: 12.42
# 2019-05-31, Close, 123.68
# 2019-05-31, y_pred, -1.00
# 2019-05-31, SELL ORDER CREATED, 123.68
# 2019-06-03, SELL ORDER EXECUTED, Price: 123.85, Cost: 12423.00, Commission: 12.38
# 2019-06-03, OPERATING PROFIT, GROSS: -38.00, NET: -62.81
# 2019-06-03, Close, 119.84
# 2019-06-03, y_pred, -1.00
# 2019-06-04, Close, 123.16
# 2019-06-04, y_pred, 1.00
# 2019-06-04, BUY ORDER CREATED, 123.16
# 2019-06-05, BUY ORDER EXECUTED, Price: 124.95, Cost: 12495.00, Commission: 12.49
# 2019-06-05, Close, 125.83
# 2019-06-05, y_pred, 1.00
# 2019-06-06, Close, 127.82
# 2019-06-06, y_pred, 1.00
# 2019-06-07, Close, 131.40
# 2019-06-07, y_pred, 1.00
# 2019-06-10, Close, 132.60
# 2019-06-10, y_pred, 1.00
# 2019-06-11, Close, 132.10
# 2019-06-11, y_pred, 1.00
# 2019-06-12, Close, 131.49
# 2019-06-12, y_pred, -1.00
# 2019-06-12, SELL ORDER CREATED, 131.49
# 2019-06-13, SELL ORDER EXECUTED, Price: 131.98, Cost: 12495.00, Commission: 13.20
# 2019-06-13, OPERATING PROFIT, GROSS: 703.00, NET: 677.31
# 2019-06-13, Close, 132.32
# 2019-06-13, y_pred, 1.00
# 2019-06-13, BUY ORDER CREATED, 132.32
# 2019-06-14, BUY ORDER EXECUTED, Price: 132.26, Cost: 13226.00, Commission: 13.23
# 2019-06-14, Close, 132.45
# 2019-06-14, y_pred, 1.00
# 2019-06-17, Close, 132.85
# 2019-06-17, y_pred, 1.00
# 2019-06-18, Close, 135.16
# 2019-06-18, y_pred, 1.00
# 2019-06-19, Close, 135.69
# 2019-06-19, y_pred, 1.00
# 2019-06-20, Close, 136.95
# 2019-06-20, y_pred, 1.00
# 2019-06-21, Close, 136.97
# 2019-06-21, y_pred, 1.00
# 2019-06-24, Close, 137.78
# 2019-06-24, y_pred, 1.00
# 2019-06-25, Close, 133.43
# 2019-06-25, y_pred, -1.00
# 2019-06-25, SELL ORDER CREATED, 133.43
# 2019-06-26, SELL ORDER EXECUTED, Price: 134.35, Cost: 13226.00, Commission: 13.44
# 2019-06-26, OPERATING PROFIT, GROSS: 209.00, NET: 182.34
# 2019-06-26, Close, 133.93
# 2019-06-26, y_pred, -1.00
# 2019-06-27, Close, 134.15
# 2019-06-27, y_pred, -1.00
# 2019-06-28, Close, 133.96
# 2019-06-28, y_pred, 1.00
# 2019-06-28, BUY ORDER CREATED, 133.96
# 2019-07-01, BUY ORDER EXECUTED, Price: 136.63, Cost: 13663.00, Commission: 13.66
# 2019-07-01, Close, 135.68
# 2019-07-01, y_pred, 1.00
# 2019-07-02, Close, 136.58
# 2019-07-02, y_pred, 1.00
# 2019-07-03, Close, 137.46
# 2019-07-03, y_pred, 1.00
# 2019-07-05, Close, 137.06
# 2019-07-05, y_pred, 1.00
# 2019-07-08, Close, 136.96
# 2019-07-08, y_pred, -1.00
# 2019-07-08, SELL ORDER CREATED, 136.96
# 2019-07-09, SELL ORDER EXECUTED, Price: 136.00, Cost: 13663.00, Commission: 13.60
# 2019-07-09, OPERATING PROFIT, GROSS: -63.00, NET: -90.26
# 2019-07-09, Close, 136.46
# 2019-07-09, y_pred, -1.00
# 2019-07-10, Close, 137.85
# 2019-07-10, y_pred, 1.00
# 2019-07-10, BUY ORDER CREATED, 137.85
# 2019-07-11, BUY ORDER EXECUTED, Price: 138.20, Cost: 13820.00, Commission: 13.82
# 2019-07-11, Close, 138.40
# 2019-07-11, y_pred, 1.00
# 2019-07-12, Close, 138.90
# 2019-07-12, y_pred, 1.00
# 2019-07-15, Close, 138.90
# 2019-07-15, y_pred, 1.00
# 2019-07-16, Close, 137.08
# 2019-07-16, y_pred, -1.00
# 2019-07-16, SELL ORDER CREATED, 137.08
# 2019-07-17, SELL ORDER EXECUTED, Price: 137.70, Cost: 13820.00, Commission: 13.77
# 2019-07-17, OPERATING PROFIT, GROSS: -50.00, NET: -77.59
# 2019-07-17, Close, 136.27
# 2019-07-17, y_pred, -1.00
# 2019-07-18, Close, 136.42
# 2019-07-18, y_pred, -1.00
# 2019-07-19, Close, 136.62
# 2019-07-19, y_pred, 1.00
# 2019-07-19, BUY ORDER CREATED, 136.62
# 2019-07-22, BUY ORDER EXECUTED, Price: 137.41, Cost: 13741.00, Commission: 13.74
# 2019-07-22, Close, 138.43
# 2019-07-22, y_pred, 1.00
# 2019-07-23, Close, 139.29
# 2019-07-23, y_pred, 1.00
# 2019-07-24, Close, 140.72
# 2019-07-24, y_pred, 1.00
# 2019-07-25, Close, 140.19
# 2019-07-25, y_pred, 1.00
# 2019-07-26, Close, 141.34
# 2019-07-26, y_pred, 1.00
# 2019-07-29, Close, 141.03
# 2019-07-29, y_pred, 1.00
# 2019-07-30, Close, 140.35
# 2019-07-30, y_pred, -1.00
# 2019-07-30, SELL ORDER CREATED, 140.35
# 2019-07-31, SELL ORDER EXECUTED, Price: 140.33, Cost: 13741.00, Commission: 14.03
# 2019-07-31, OPERATING PROFIT, GROSS: 292.00, NET: 264.23
# 2019-07-31, Close, 136.27
# 2019-07-31, y_pred, -1.00
# 2019-08-01, Close, 138.06
# 2019-08-01, y_pred, -1.00
# 2019-08-02, Close, 136.90
# 2019-08-02, y_pred, -1.00
# 2019-08-05, Close, 132.21
# 2019-08-05, y_pred, -1.00
# 2019-08-06, Close, 134.69
# 2019-08-06, y_pred, -1.00
# 2019-08-07, Close, 135.28
# 2019-08-07, y_pred, 1.00
# 2019-08-07, BUY ORDER CREATED, 135.28
# 2019-08-08, BUY ORDER EXECUTED, Price: 136.60, Cost: 13660.00, Commission: 13.66
# 2019-08-08, Close, 138.89
# 2019-08-08, y_pred, 1.00
# 2019-08-09, Close, 137.71
# 2019-08-09, y_pred, 1.00
# 2019-08-12, Close, 135.79
# 2019-08-12, y_pred, -1.00
# 2019-08-12, SELL ORDER CREATED, 135.79
# 2019-08-13, SELL ORDER EXECUTED, Price: 136.05, Cost: 13660.00, Commission: 13.61
# 2019-08-13, OPERATING PROFIT, GROSS: -55.00, NET: -82.27
# 2019-08-13, Close, 138.60
# 2019-08-13, y_pred, 1.00
# 2019-08-13, BUY ORDER CREATED, 138.60
# 2019-08-14, BUY ORDER EXECUTED, Price: 136.36, Cost: 13636.00, Commission: 13.64
# 2019-08-14, Close, 133.98
# 2019-08-14, y_pred, -1.00
# 2019-08-14, SELL ORDER CREATED, 133.98
# 2019-08-15, SELL ORDER EXECUTED, Price: 134.39, Cost: 13636.00, Commission: 13.44
# 2019-08-15, OPERATING PROFIT, GROSS: -197.00, NET: -224.08
# 2019-08-15, Close, 133.68
# 2019-08-15, y_pred, -1.00
# 2019-08-16, Close, 136.13
# 2019-08-16, y_pred, 1.00
# 2019-08-16, BUY ORDER CREATED, 136.13
# 2019-08-19, BUY ORDER EXECUTED, Price: 137.85, Cost: 13785.00, Commission: 13.79
# 2019-08-19, Close, 138.41
# 2019-08-19, y_pred, 1.00
# 2019-08-20, Close, 137.26
# 2019-08-20, y_pred, 1.00
# 2019-08-21, Close, 138.79
# 2019-08-21, y_pred, 1.00
# 2019-08-22, Close, 137.78
# 2019-08-22, y_pred, -1.00
# 2019-08-22, SELL ORDER CREATED, 137.78
# 2019-08-23, SELL ORDER EXECUTED, Price: 137.19, Cost: 13785.00, Commission: 13.72
# 2019-08-23, OPERATING PROFIT, GROSS: -66.00, NET: -93.50
# 2019-08-23, Close, 133.39
# 2019-08-23, y_pred, -1.00
# 2019-08-26, Close, 135.45
# 2019-08-26, y_pred, -1.00
# 2019-08-27, Close, 135.74
# 2019-08-27, y_pred, -1.00
# 2019-08-28, Close, 135.56
# 2019-08-28, y_pred, 1.00
# 2019-08-28, BUY ORDER CREATED, 135.56
# 2019-08-29, BUY ORDER EXECUTED, Price: 137.25, Cost: 13725.00, Commission: 13.73
# 2019-08-29, Close, 138.12
# 2019-08-29, y_pred, 1.00
# 2019-08-30, Close, 137.86
# 2019-08-30, y_pred, 1.00
# 2019-09-03, Close, 136.04
# 2019-09-03, y_pred, -1.00
# 2019-09-03, SELL ORDER CREATED, 136.04
# 2019-09-04, SELL ORDER EXECUTED, Price: 137.30, Cost: 13725.00, Commission: 13.73
# 2019-09-04, OPERATING PROFIT, GROSS: 5.00, NET: -22.45
# 2019-09-04, Close, 137.63
# 2019-09-04, y_pred, -1.00
# 2019-09-05, Close, 140.05
# 2019-09-05, y_pred, 1.00
# 2019-09-05, BUY ORDER CREATED, 140.05
# 2019-09-06, BUY ORDER EXECUTED, Price: 140.03, Cost: 14003.00, Commission: 14.00
# 2019-09-06, Close, 139.10
# 2019-09-06, y_pred, 1.00
# 2019-09-09, Close, 137.52
# 2019-09-09, y_pred, -1.00
# 2019-09-09, SELL ORDER CREATED, 137.52
# 2019-09-10, SELL ORDER EXECUTED, Price: 136.80, Cost: 14003.00, Commission: 13.68
# 2019-09-10, OPERATING PROFIT, GROSS: -323.00, NET: -350.68
# 2019-09-10, Close, 136.08
# 2019-09-10, y_pred, -1.00
# 2019-09-11, Close, 136.12
# 2019-09-11, y_pred, -1.00
# 2019-09-12, Close, 137.52
# 2019-09-12, y_pred, 1.00
# 2019-09-12, BUY ORDER CREATED, 137.52
# 2019-09-13, BUY ORDER EXECUTED, Price: 137.78, Cost: 13778.00, Commission: 13.78
# 2019-09-13, Close, 137.32
# 2019-09-13, y_pred, 1.00
# 2019-09-16, Close, 136.33
# 2019-09-16, y_pred, -1.00
# 2019-09-16, SELL ORDER CREATED, 136.33
# 2019-09-17, SELL ORDER EXECUTED, Price: 136.96, Cost: 13778.00, Commission: 13.70
# 2019-09-17, OPERATING PROFIT, GROSS: -82.00, NET: -109.47
# 2019-09-17, Close, 137.39
# 2019-09-17, y_pred, 1.00
# 2019-09-17, BUY ORDER CREATED, 137.39
# 2019-09-18, BUY ORDER EXECUTED, Price: 137.36, Cost: 13736.00, Commission: 13.74
# 2019-09-18, Close, 138.52
# 2019-09-18, y_pred, 1.00
# 2019-09-19, Close, 141.07
# 2019-09-19, y_pred, 1.00
# 2019-09-20, Close, 139.44
# 2019-09-20, y_pred, -1.00
# 2019-09-20, SELL ORDER CREATED, 139.44
# 2019-09-23, SELL ORDER EXECUTED, Price: 139.23, Cost: 13736.00, Commission: 13.92
# 2019-09-23, OPERATING PROFIT, GROSS: 187.00, NET: 159.34
# 2019-09-23, Close, 139.14
# 2019-09-23, y_pred, -1.00
# 2019-09-24, Close, 137.38
# 2019-09-24, y_pred, -1.00
# 2019-09-25, Close, 139.36
# 2019-09-25, y_pred, 1.00
# 2019-09-25, BUY ORDER CREATED, 139.36
# 2019-09-26, BUY ORDER EXECUTED, Price: 139.44, Cost: 13944.00, Commission: 13.94
# 2019-09-26, Close, 139.54
# 2019-09-26, y_pred, 1.00
# 2019-09-27, Close, 137.73
# 2019-09-27, y_pred, -1.00
# 2019-09-27, SELL ORDER CREATED, 137.73
# 2019-09-30, SELL ORDER EXECUTED, Price: 138.05, Cost: 13944.00, Commission: 13.81
# 2019-09-30, OPERATING PROFIT, GROSS: -139.00, NET: -166.75
# 2019-09-30, Close, 139.03
# 2019-09-30, y_pred, 1.00
# 2019-09-30, BUY ORDER CREATED, 139.03
# 2019-10-01, BUY ORDER EXECUTED, Price: 139.66, Cost: 13966.00, Commission: 13.97
# 2019-10-01, Close, 137.07
# 2019-10-01, y_pred, -1.00
# 2019-10-01, SELL ORDER CREATED, 137.07
# 2019-10-02, SELL ORDER EXECUTED, Price: 136.25, Cost: 13966.00, Commission: 13.62
# 2019-10-02, OPERATING PROFIT, GROSS: -341.00, NET: -368.59
# 2019-10-02, Close, 134.65
# 2019-10-02, y_pred, -1.00
# 2019-10-03, Close, 136.28
# 2019-10-03, y_pred, -1.00
# 2019-10-04, Close, 138.12
# 2019-10-04, y_pred, 1.00
# 2019-10-04, BUY ORDER CREATED, 138.12
# 2019-10-07, BUY ORDER EXECUTED, Price: 137.14, Cost: 13714.00, Commission: 13.71
# 2019-10-07, Close, 137.12
# 2019-10-07, y_pred, 1.00
# 2019-10-08, Close, 135.67
# 2019-10-08, y_pred, -1.00
# 2019-10-08, SELL ORDER CREATED, 135.67
# 2019-10-09, SELL ORDER EXECUTED, Price: 137.46, Cost: 13714.00, Commission: 13.75
# 2019-10-09, OPERATING PROFIT, GROSS: 32.00, NET: 4.54
# 2019-10-09, Close, 138.24
# 2019-10-09, y_pred, 1.00
# 2019-10-09, BUY ORDER CREATED, 138.24
# 2019-10-10, BUY ORDER EXECUTED, Price: 138.49, Cost: 13849.00, Commission: 13.85
# 2019-10-10, Close, 139.10
# 2019-10-10, y_pred, 1.00
# 2019-10-11, Close, 139.68
# 2019-10-11, y_pred, 1.00
# 2019-10-14, Close, 139.55
# 2019-10-14, y_pred, 1.00
# 2019-10-15, Close, 141.57
# 2019-10-15, y_pred, 1.00
# 2019-10-16, Close, 140.41
# 2019-10-16, y_pred, -1.00
# 2019-10-16, SELL ORDER CREATED, 140.41
# 2019-10-17, SELL ORDER EXECUTED, Price: 140.95, Cost: 13849.00, Commission: 14.09
# 2019-10-17, OPERATING PROFIT, GROSS: 246.00, NET: 218.06
# 2019-10-17, Close, 139.69
# 2019-10-17, y_pred, -1.00
# 2019-10-18, Close, 137.41
# 2019-10-18, y_pred, -1.00
# 2019-10-21, Close, 138.43
# 2019-10-21, y_pred, -1.00
# 2019-10-22, Close, 136.37
# 2019-10-22, y_pred, -1.00
# 2019-10-23, Close, 137.24
# 2019-10-23, y_pred, 1.00
# 2019-10-23, BUY ORDER CREATED, 137.24
# 2019-10-24, BUY ORDER EXECUTED, Price: 139.39, Cost: 13939.00, Commission: 13.94
# 2019-10-24, Close, 139.94
# 2019-10-24, y_pred, 1.00
# 2019-10-25, Close, 140.73
# 2019-10-25, y_pred, 1.00
# 2019-10-28, Close, 144.19
# 2019-10-28, y_pred, 1.00
# 2019-10-29, Close, 142.83
# 2019-10-29, y_pred, 1.00
# 2019-10-30, Close, 144.61
# 2019-10-30, y_pred, 1.00
# 2019-10-31, Close, 143.37
# 2019-10-31, y_pred, -1.00
# 2019-10-31, SELL ORDER CREATED, 143.37
# 2019-11-01, SELL ORDER EXECUTED, Price: 144.26, Cost: 13939.00, Commission: 14.43
# 2019-11-01, OPERATING PROFIT, GROSS: 487.00, NET: 458.63
# 2019-11-01, Close, 143.72
# 2019-11-01, y_pred, 1.00
# 2019-11-01, BUY ORDER CREATED, 143.72
# 2019-11-04, BUY ORDER EXECUTED, Price: 144.83, Cost: 14483.00, Commission: 14.48
# 2019-11-04, Close, 144.55
# 2019-11-04, y_pred, 1.00
# 2019-11-05, Close, 144.46
# 2019-11-05, y_pred, 1.00
# 2019-11-06, Close, 144.06
# 2019-11-06, y_pred, 1.00
# 2019-11-07, Close, 144.26
# 2019-11-07, y_pred, 1.00
# 2019-11-08, Close, 145.96
# 2019-11-08, y_pred, 1.00
# 2019-11-11, Close, 146.11
# 2019-11-11, y_pred, 1.00
# 2019-11-12, Close, 147.07
# 2019-11-12, y_pred, 1.00
# 2019-11-13, Close, 147.31
# 2019-11-13, y_pred, 1.00
# 2019-11-14, Close, 148.06
# 2019-11-14, y_pred, 1.00
# 2019-11-15, Close, 149.97
# 2019-11-15, y_pred, 1.00
# 2019-11-18, Close, 150.34
# 2019-11-18, y_pred, 1.00
# 2019-11-19, Close, 150.39
# 2019-11-19, y_pred, 1.00
# 2019-11-20, Close, 149.62
# 2019-11-20, y_pred, -1.00
# 2019-11-20, SELL ORDER CREATED, 149.62
# 2019-11-21, SELL ORDER EXECUTED, Price: 149.40, Cost: 14483.00, Commission: 14.94
# 2019-11-21, OPERATING PROFIT, GROSS: 457.00, NET: 427.58
# 2019-11-21, Close, 149.48
# 2019-11-21, y_pred, -1.00
# 2019-11-22, Close, 149.59
# 2019-11-22, y_pred, 1.00
# 2019-11-22, BUY ORDER CREATED, 149.59
# 2019-11-25, BUY ORDER EXECUTED, Price: 150.00, Cost: 15000.00, Commission: 15.00
# 2019-11-25, Close, 151.23
# 2019-11-25, y_pred, 1.00
# 2019-11-26, Close, 152.03
# 2019-11-26, y_pred, 1.00
# 2019-11-27, Close, 152.32
# 2019-11-27, y_pred, 1.00
# 2019-11-29, Close, 151.38
# 2019-11-29, y_pred, -1.00
# 2019-11-29, SELL ORDER CREATED, 151.38
# 2019-12-02, SELL ORDER EXECUTED, Price: 151.81, Cost: 15000.00, Commission: 15.18
# 2019-12-02, OPERATING PROFIT, GROSS: 181.00, NET: 150.82
# 2019-12-02, Close, 149.55
# 2019-12-02, y_pred, -1.00
# 2019-12-03, Close, 149.31
# 2019-12-03, y_pred, -1.00
# 2019-12-04, Close, 149.85
# 2019-12-04, y_pred, -1.00
# 2019-12-05, Close, 149.93
# 2019-12-05, y_pred, -1.00
# 2019-12-06, Close, 151.75
# 2019-12-06, y_pred, 1.00
# 2019-12-06, BUY ORDER CREATED, 151.75
# 2019-12-09, BUY ORDER EXECUTED, Price: 151.07, Cost: 15107.00, Commission: 15.11
# 2019-12-09, Close, 151.36
# 2019-12-09, y_pred, 1.00
# 2019-12-10, Close, 151.13
# 2019-12-10, y_pred, -1.00
# 2019-12-10, SELL ORDER CREATED, 151.13
# 2019-12-11, SELL ORDER EXECUTED, Price: 151.54, Cost: 15107.00, Commission: 15.15
# 2019-12-11, OPERATING PROFIT, GROSS: 47.00, NET: 16.74
# 2019-12-11, Close, 151.70
# 2019-12-11, y_pred, 1.00
# 2019-12-11, BUY ORDER CREATED, 151.70
# 2019-12-12, BUY ORDER EXECUTED, Price: 151.65, Cost: 15165.00, Commission: 15.16
# 2019-12-12, Close, 153.24
# 2019-12-12, y_pred, 1.00
# 2019-12-13, Close, 154.53
# 2019-12-13, y_pred, 1.00
# 2019-12-16, Close, 155.53
# 2019-12-16, y_pred, 1.00
# 2019-12-17, Close, 154.69
# 2019-12-17, y_pred, 1.00
# 2019-12-18, Close, 154.37
# 2019-12-18, y_pred, -1.00
# 2019-12-18, SELL ORDER CREATED, 154.37
# 2019-12-19, SELL ORDER EXECUTED, Price: 154.00, Cost: 15165.00, Commission: 15.40
# 2019-12-19, OPERATING PROFIT, GROSS: 235.00, NET: 204.44
# 2019-12-19, Close, 155.71
# 2019-12-19, y_pred, 1.00
# 2019-12-19, BUY ORDER CREATED, 155.71
# 2019-12-20, BUY ORDER EXECUTED, Price: 157.35, Cost: 15735.00, Commission: 15.74
# 2019-12-20, Close, 157.41
# 2019-12-20, y_pred, 1.00
# 2019-12-23, Close, 157.41
# 2019-12-23, y_pred, 1.00
# 2019-12-24, Close, 157.38
# 2019-12-24, y_pred, 1.00
# 2019-12-26, Close, 158.67
# 2019-12-26, y_pred, 1.00
# 2019-12-27, Close, 158.96
# 2019-12-27, y_pred, 1.00
# 2019-12-30, Close, 157.59
# 2019-12-30, y_pred, -1.00
# 2019-12-30, SELL ORDER CREATED, 157.59
#
# Final Portfolio Value: 1001747.44
# Trade Analysis Results:
#                Total Open     Total Closed   Total Won      Total Lost
#                1              40             20             20
#                Strike Rate    Win Streak     Losing Streak  PnL Net
#                50.0           7              6              1739.17
# <img src="data:image/png;base64,..." width="432">
# [[<Figure size 432x288 with 4 Axes>]]
